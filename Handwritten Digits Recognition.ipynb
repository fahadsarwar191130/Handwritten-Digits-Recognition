# %%
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
for i in range(10):
    plt.matshow(X_train[i])

# %%
y_train[:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %%
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_test_flattened.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(10, input_shape= (784,), activation="sigmoid")
    
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 9.3809 - accuracy: 0.8414
# Epoch 2/5
# 1875/1875 [==============================] - 2s 899us/step - loss: 6.1385 - accuracy: 0.8774
# Epoch 3/5
# 1875/1875 [==============================] - 2s 916us/step - loss: 5.6762 - accuracy: 0.8843
# Epoch 4/5
# 1875/1875 [==============================] - 2s 932us/step - loss: 5.5245 - accuracy: 0.8841
# Epoch 5/5
# 1875/1875 [==============================] - 2s 913us/step - loss: 5.2572 - accuracy: 0.8874

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(100, input_shape= (784,), activation="sigmoid"),
    keras.layers.Dense(10, activation="sigmoid")
    
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5743 - accuracy: 0.8453
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3660 - accuracy: 0.8940
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3454 - accuracy: 0.8971
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3167 - accuracy: 0.9061
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2943 - accuracy: 0.9118

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(500, input_shape= (784,), activation="relu"),
    keras.layers.Dense(100, activation="relu"),
    keras.layers.Dense(10, activation="relu")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 9.7861 - accuracy: 0.1205
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 11.0316 - accuracy: 0.1028
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 11.0316 - accuracy: 0.1028
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 11.0316 - accuracy: 0.1028
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 11.0316 - accuracy: 0.1028

# %%
model = keras.Sequential([
    #Layer 1
    keras.layers.Dense(512, input_shape= (784,), activation="sigmoid"),
    keras.layers.Dense(256, activation="sigmoid"),
    keras.layers.Dense(10, activation="sigmoid")
])

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

model.fit(X_train_flattened, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.4230 - accuracy: 0.8860
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2788 - accuracy: 0.9152
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2547 - accuracy: 0.9208
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2386 - accuracy: 0.9259
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2150 - accuracy: 0.9331
# Epoch 6/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1978 - accuracy: 0.9382
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1926 - accuracy: 0.9407
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1844 - accuracy: 0.9422
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.1694 - accuracy: 0.9477
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1627 - accuracy: 0.9494

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1723 - accuracy: 0.9477
# [0.17231594026088715, 0.947700023651123]

# %%
y_pred = model.predict(X_test_flattened)

# %%
y_pred[0]
# Out:
# array([1.0122895e-02, 4.9783021e-02, 6.2987924e-01, 7.5595415e-01,
#        5.4308772e-04, 7.0113719e-02, 1.0864838e-06, 9.9933970e-01,
#        3.9695263e-02, 5.1602423e-01], dtype=float32)

# %%
np.argmax(y_pred[0])
# Out:
# 7

# %%
plt.matshow(X_test[0])

# %%
def find(index):
    result = np.argmax(y_pred[index])
    plt.matshow(X_test[index])
    plt.xlabel(result, size = 20)

# %%
for i in range(500,600):
    find(i)
# Out:
# C:\Users\FAHADB~1\AppData\Local\Temp/ipykernel_28552/1361225994.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.matshow(X_test[index])

# %%
y_predicted_labels = [np.argmax(i) for i in y_pred]
y_predicted_labels[:5]
# Out:
# [7, 2, 1, 0, 4]

# %%
y_test[:5]
# Out:
# array([7, 2, 1, 0, 4], dtype=uint8)

# %%
cm = tf.math.confusion_matrix(labels= y_test, predictions = y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 954,    0,    3,    2,    1,    3,    9,    1,    5,    2],
#        [   0, 1113,    3,    3,    0,    1,    2,    0,   13,    0],
#        [   8,    0,  994,    8,    5,    1,    5,    5,    5,    1],
#        [   1,    0,    8,  977,    0,    6,    0,    6,   11,    1],
#        [   2,    1,   10,    0,  923,    2,    3,    0,    7,   34],
#        [   7,    2,    1,   36,    1,  822,    7,    1,   11,    4],
#        [   7,    3,    4,    0,    6,    6,  924,    0,    8,    0],
#        [   2,    4,   21,   19,    5,    2,    0,  950,    6,   19],
#        [   4,    0,   16,   31,    5,    4,    8,    0,  898,    8],
#        [   3,    6,    4,   17,   24,   14,    0,    9,   10,  922]])>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
# Out:
# <AxesSubplot:>
